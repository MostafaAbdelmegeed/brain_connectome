# %%
import torch

# %%
ds = torch.load('../data/ppmi_raw.pth')
ds
# Out:
# [Data(x=[116, 116], edge_index=[2, 6670], edge_attr=[6670], y=0),
#  Data(x=[116, 116], edge_index=[2, 6670], edge_attr=[6670], y=0),
#  Data(x=[116, 116], edge_index=[2, 6670], edge_attr=[6670], y=0),
#  Data(x=[116, 116], edge_index=[2, 6670], edge_attr=[6670], y=0),
#  Data(x=[116, 116], edge_index=[2, 6670], edge_attr=[6670], y=0),
#  Data(x=[116, 116], edge_index=[2, 6670], edge_attr=[6670], y=0),
#  Data(x=[116, 116], edge_index=[2, 6670], edge_attr=[6670], y=0),
#  Data(x=[116, 116], edge_index=[2, 6670], edge_attr=[6670], y=0),
#  Data(x=[116, 116], edge_index=[2, 6670], edge_attr=[6670], y=0),
#  Data(x=[116, 116], edge_index=[2, 6670], edge_attr=[6670], y=0),
#  Data(x=[116, 116], edge_index=[2, 6670], edge_attr=[6670], y=0),
#  Data(x=[116, 116], edge_index=[2, 6670], edge_attr=[6670], y=0),
#  Data(x=[116, 116], edge_index=[2, 6670], edge_attr=[6670], y=0),
#  Data(x=[116, 116], edge_index=[2, 6670], edge_attr=[6670], y=0),
# ...

# %%
# lr = torch.load('../data/LR_dataset.pth')
# Out:
# [Data(x=[360, 360], edge_index=[2, 12960], edge_attr=[12960], y=0),
#  Data(x=[360, 360], edge_index=[2, 12960], edge_attr=[12960], y=1),
#  Data(x=[360, 360], edge_index=[2, 12960], edge_attr=[12960], y=2),
#  Data(x=[360, 360], edge_index=[2, 12960], edge_attr=[12960], y=3),
#  Data(x=[360, 360], edge_index=[2, 12960], edge_attr=[12960], y=4),
#  Data(x=[360, 360], edge_index=[2, 12960], edge_attr=[12960], y=5),
#  Data(x=[360, 360], edge_index=[2, 12960], edge_attr=[12960], y=6),
#  Data(x=[360, 360], edge_index=[2, 12960], edge_attr=[12960], y=0),
#  Data(x=[360, 360], edge_index=[2, 12960], edge_attr=[12960], y=1),
#  Data(x=[360, 360], edge_index=[2, 12960], edge_attr=[12960], y=2),
#  Data(x=[360, 360], edge_index=[2, 12960], edge_attr=[12960], y=3),
#  Data(x=[360, 360], edge_index=[2, 12960], edge_attr=[12960], y=4),
#  Data(x=[360, 360], edge_index=[2, 12962], edge_attr=[12962], y=5),
#  Data(x=[360, 360], edge_index=[2, 12960], edge_attr=[12960], y=6),
# ...
